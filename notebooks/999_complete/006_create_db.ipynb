# %%
import sys
# 프로젝트 루트 직접 지정
sys.path.insert(0, r"c:\Users\tjrrj\vscode\doritest")

# %%
from modules import nb_read_table, nb_get_db_url

# 연결 문자열
url = nb_get_db_url()  # postgresql://doridang:doridang@127.0.0.1:5434/doridangdb

# %%
from modules import nb_get_db_url
from sqlalchemy import create_engine, text

# %%
# 셀 4번 실행
engine = create_engine(nb_get_db_url())

with engine.connect() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS doridang"))
    conn.commit()
    
    create_table_sql = """
    CREATE TABLE IF NOT EXISTS doridang.baemin_sales (
        order_id TEXT PRIMARY KEY,
        store_id TEXT,
        order_time TIMESTAMP,
        order_amount NUMERIC,
        created_at TIMESTAMP DEFAULT NOW()
    )
    """
    conn.execute(text(create_table_sql))
    conn.commit()
    print("✅ 스키마 및 테이블 생성 완료")

engine.dispose()
